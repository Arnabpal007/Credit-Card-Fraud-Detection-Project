# %% [markdown]
# # Credit Card Fraud Detection Project
#
# In this project we will be working with a creditcard data set, indicating whether a perticular transaction in our collected data is Legit or Fraud.
# We will try to create a model that will predict whether the transaction is Legit or Fraud.
#
# In our creditcard data set:
# * '0': Legit Transaction
# * '1': Fraud Transaction

# %% [markdown]
# ## Import Libraries
#
# **Importing required libraries**

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline

# %% [markdown]
# ## Get the Data
# **Reading the creditcard.csv file and set it to a data frame called creditcard_data.**

# %%
creditcard_data=pd.read_csv('creditcard.csv')

# %% [markdown]
# **Checking the head of creditcard_data.**

# %%
creditcard_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# **Using info() and describe() on creditcard_data.**

# %%
creditcard_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
creditcard_data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %% [markdown]
# ## Exploratory Data Analysis
#
# **Let's explore the data.**

# %% [markdown]
# **Checking number of rows and columns.**

# %%
creditcard_data.shape
# Out:
# (284807, 31)

# %% [markdown]
# **Creating a countplot showing how many of the transactions are Legit or Fraud in the data.**

# %%
fig=plt.figure(figsize=(10,6))
fig.patch.set_facecolor('xkcd:mint green')
cp=sns.countplot(x='Class',data=creditcard_data)
for p in cp.patches:
   cp.annotate('{:}'.format(p.get_height()), (p.get_x()+0.36, p.get_height()+0.01))

# %% [markdown]
# **We can see that the data set is highly unbalanced.**

# %% [markdown]
# **Separating the data for more analysis.**

# %%
legit_data=creditcard_data[creditcard_data['Class']==0]
fraud_data=creditcard_data[creditcard_data['Class']==1]

# %%
print(legit_data.shape)
print(fraud_data.shape)
# Out:
# (284315, 31)
# (492, 31)

# %% [markdown]
# **Analysing the legit_data and fraud_data statically.**

# %%
legit_data.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  284315.000000  284315.000000  284315.000000  284315.000000
# mean    94838.202258       0.008258      -0.006271       0.012171
# std     47484.015786       1.929814       1.636146       1.459429
# min         0.000000     -56.407510     -72.715728     -48.325589
# 25%     54230.000000      -0.917544      -0.599473      -0.884541
# 50%     84711.000000       0.020023       0.064070       0.182158
# 75%    139333.000000       1.316218       0.800446       1.028372
# max    172792.000000       2.454930      18.902453       9.382558
#
#                   V4             V5             V6             V7  \
# count  284315.000000  284315.000000  284315.000000  284315.000000
# mean       -0.007860       0.005453       0.002419       0.009637
# std         1.399333       1.356952       1.329913       1.178812
# min        -5.683171    -113.743307     -26.160506     -31.764946
# ...

# %%
fraud_data.describe()
# Out:
#                 Time          V1          V2          V3          V4  \
# count     492.000000  492.000000  492.000000  492.000000  492.000000
# mean    80746.806911   -4.771948    3.623778   -7.033281    4.542029
# std     47835.365138    6.783687    4.291216    7.110937    2.873318
# min       406.000000  -30.552380   -8.402154  -31.103685   -1.313275
# 25%     41241.500000   -6.036063    1.188226   -8.643489    2.373050
# 50%     75568.500000   -2.342497    2.717869   -5.075257    4.177147
# 75%    128483.000000   -0.419200    4.971257   -2.276185    6.348729
# max    170348.000000    2.132386   22.057729    2.250210   12.114672
#
#                V5          V6          V7          V8          V9  ...  \
# count  492.000000  492.000000  492.000000  492.000000  492.000000  ...
# mean    -3.151225   -1.397737   -5.568731    0.570636   -2.581123  ...
# std      5.372468    1.858124    7.206773    6.797831    2.500896  ...
# ...

# %% [markdown]
# **Comparing the mean of each columns of the creditcard_data  based on wheather the transaction is Legit or Fraud using groupby.**

# %%
creditcard_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# ## Under-Sampling
# **Building a sample data set containg the similar distribution of Legit and Fraud Transactions.**

# %% [markdown]
# **Creating a sample of legit_data.**

# %%
sample_legit_data=legit_data.sample(n=492)

# %%
sample_legit_data.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 243154  151823.0  1.903235 -0.014539 -0.358505  0.554961 -0.840169 -1.487588
# 267639  162856.0 -0.620362  0.273959  1.628905 -0.739699  0.754977  1.118416
# 73616    55206.0  1.174399  0.284581  0.285488  1.079841 -0.086260 -0.451772
# 8800     12003.0  1.011798  0.008788  0.566955  1.583304 -0.292573  0.059420
# 89262    62500.0  1.178626 -0.556939  0.813911  0.571285 -1.119314 -0.105282
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 243154 -0.268778 -0.261200  0.976029  ... -0.176105 -0.301056  0.448722
# 267639  0.324302  0.184660  0.668307  ...  0.324922  1.425051 -0.117726
# 73616   0.143539 -0.120166 -0.063475  ...  0.179863  0.614228 -0.153021
# 8800   -0.154264  0.107526  1.515394  ... -0.173241 -0.237995 -0.064766
# 89262  -0.754194  0.107045 -0.629735  ... -0.202418 -0.187451  0.018285
#
# ...

# %%
sample_legit_data.shape
# Out:
# (492, 31)

# %% [markdown]
# **Concatenating sample_legit_data and fraud_data to create a new well-balanced creditcard data.**

# %%
new_creditcard_data=pd.concat((sample_legit_data,fraud_data),axis=0)

# %%
new_creditcard_data.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 243154  151823.0  1.903235 -0.014539 -0.358505  0.554961 -0.840169 -1.487588
# 267639  162856.0 -0.620362  0.273959  1.628905 -0.739699  0.754977  1.118416
# 73616    55206.0  1.174399  0.284581  0.285488  1.079841 -0.086260 -0.451772
# 8800     12003.0  1.011798  0.008788  0.566955  1.583304 -0.292573  0.059420
# 89262    62500.0  1.178626 -0.556939  0.813911  0.571285 -1.119314 -0.105282
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 243154 -0.268778 -0.261200  0.976029  ... -0.176105 -0.301056  0.448722
# 267639  0.324302  0.184660  0.668307  ...  0.324922  1.425051 -0.117726
# 73616   0.143539 -0.120166 -0.063475  ...  0.179863  0.614228 -0.153021
# 8800   -0.154264  0.107526  1.515394  ... -0.173241 -0.237995 -0.064766
# 89262  -0.754194  0.107045 -0.629735  ... -0.202418 -0.187451  0.018285
#
# ...

# %%
new_creditcard_data['Class'].value_counts()
# Out:
# 1    492
# 0    492
# Name: Class, dtype: int64

# %% [markdown]
# **Now we can make our ML model based on this new well-balanced data set.**

# %% [markdown]
# ## Logistic Regression Model
# Now we have to create a Logistic Regression Model for our data set.

# %% [markdown]
# **Split the data into training set and testing set using train_test_split.**

# %%
from sklearn.model_selection import train_test_split

# %%
X=new_creditcard_data.drop(columns='Class',axis=1)
y=new_creditcard_data['Class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=101)

# %% [markdown]
# **Training and fitting the logistic regression model on the training set.**

# %%
from sklearn.linear_model import LogisticRegression

# %%
detectFraud_model=LogisticRegression()
detectFraud_model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Predictions and Evaluations

# %% [markdown]
# **Predicting the values for the testing data.**

# %%
predictions=detectFraud_model.predict(X_test)

# %% [markdown]
# **Creating a confusion matrix and classification report to see how well the model works.**

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[155   3]
#  [ 14 153]]

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95       158
#            1       0.98      0.92      0.95       167
#
#     accuracy                           0.95       325
#    macro avg       0.95      0.95      0.95       325
# weighted avg       0.95      0.95      0.95       325

# %% [markdown]
# **According to the confusion matrix and classification report our model is working quite well.**

# %% [markdown]
# ## Thank You for Visiting
